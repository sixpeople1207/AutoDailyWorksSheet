# %%
from pywinauto import application

app = application.Application(backend='uia').connect(title='HanyangMessenger',class_name='Chrome_WidgetWin_0')
dlg = app.window(title='HanyangMessenger')
dlg.print_control_identifiers()
# Out:
# Control Identifiers:
#
# Pane - 'HanyangMessenger'    (L951, T73, R1652, B972)
# ['Pane', 'HanyangMessenger', 'HanyangMessengerPane', 'Pane0', 'Pane1']
# child_window(title="HanyangMessenger", control_type="Pane")
#    |
# ...

# %%
static_1 = dlg.Document.Static2
static_2 = dlg.Document.Static3
static_3 = dlg.Document.Static4
static_4 = dlg.Document.Static5
static_5 = dlg.Document.Static6
static_6 = dlg.Document.Static7
doc = dlg.Document.ListBox1.ListItem1.Static

doc.click_input()
# static_2.click_input()


# contacts.print_control_identifiers()
# contacts.click()
# Bobby = contacts.ListItem2.wrapper_object()
# Bobby.double_click_input()
# app.Bobby.wait('visible
# Bobby_box = app.Bobby
# Bobby_box.call.click()
# import pprint
# text = dlg.Document.texts()[0]
# dlg.Document.ListBox5.texts()[0]
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\Dinno\anaconda3\envs\Dinno\lib\site-packages\pywinauto\application.py:250, in WindowSpecification.__resolve_control(self, criteria, timeout, retry_interval)
#     249 try:
# --> 250     ctrl = wait_until_passes(
#     251         timeout,
#     252         retry_interval,
#     253         self.__get_ctrl,
#     254         (findwindows.ElementNotFoundError,
#     255          findbestmatch.MatchError,
#     256          controls.InvalidWindowHandle,
#     257          controls.InvalidElement),
#     258         criteria)
#     260 except TimeoutError as e:
#
# File c:\Users\Dinno\anaconda3\envs\Dinno\lib\site-packages\pywinauto\timings.py:458, in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457             err.original_exception = e
# --> 458             raise err
# ...

# %%
from pywinauto import application

app = application.Application(backend='uia').connect(title='HanyangMessenger',class_name='CabinetWClass')
dlg = app.window(title='HanyangMessenger') 
dlg.print_control_identifiers()

# %%
from pywinauto import application

app = application.Application(backend='uia').connect(title='김범석, 김원철, 문진영, 민병우, 방태훈, 엄정숙, 최용훈',class_name='Chrome_WidgetWin_0')
dlg = app.window(title='김범석, 김원철, 문진영, 민병우, 방태훈, 엄정숙, 최용훈')
dlg.print_control_identifiers()
# Out:
# ---------------------------------------------------------------------------
# ElementNotFoundError                      Traceback (most recent call last)
# Cell In[2], line 3
#       1 from pywinauto import application
# ----> 3 app = application.Application(backend='uia').connect(title='김범석, 김원철, 문진영, 민병우, 방태훈, 엄정숙, 최용훈',class_name='Chrome_WidgetWin_0')
#       4 dlg = app.window(title='김범석, 김원철, 문진영, 민병우, 방태훈, 엄정숙, 최용훈')
#       5 dlg.print_control_identifiers()
#
# File c:\Users\Dinno\anaconda3\envs\Dinno\lib\site-packages\pywinauto\application.py:997, in Application.connect(self, **kwargs)
#     990         self.process = timings.wait_until_passes(
#     991                 timeout, retry_interval, findwindows.find_element,
#     992                 exceptions=(findwindows.ElementNotFoundError, findbestmatch.MatchError,
#     993                             controls.InvalidWindowHandle, controls.InvalidElement),
#     994                 *(), **kwargs
# ...

# %%
import pprint
text = dlg.Document.texts()[0]
split = text.split('\n')
index = 0
start = 0 
for sp in split:
    if '2023년 9월 6일' in sp:
        print(sp)
        start = index
    index+=1

for i in range(start,len(split)):
    print(split[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pprint
# ----> 2 text = dlg.Document.texts()[0]
#       3 split = text.split('\n')
#       4 index = 0
#
# NameError: name 'dlg' is not defined
